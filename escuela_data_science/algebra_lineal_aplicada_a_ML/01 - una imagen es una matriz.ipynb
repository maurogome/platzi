# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')

imagen = Image.open("imagenes\\tiberio.jpg")

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=599x600 at 0x19A96C06B88>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band = 0)), float)
print(imagen_mat)
# Out:
# [201. 182. 181. ...  51.   2. 237.]

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[201. 182. 181. ... 159. 160. 237.]
#  [198. 187. 185. ... 162. 164. 241.]
#  [185. 182. 181. ... 161. 163. 241.]
#  ...
#  [231. 186. 144. ...  23.  48. 234.]
#  [140.  91.  50. ...  13.  21. 238.]
#  [ 54.  60.  60. ...  51.   2. 237.]]

# %%
print(imagen_mat.shape)
# Out:
# (600, 599)

# %%
plt.imshow(imagen_mat, cmap = 'gray')
plt.show()

# %%
imagen_mat_2 = imagen_mat / 10
print(imagen_mat_2)
# Out:
# [[20.1 18.2 18.1 ... 15.9 16.  23.7]
#  [19.8 18.7 18.5 ... 16.2 16.4 24.1]
#  [18.5 18.2 18.1 ... 16.1 16.3 24.1]
#  ...
#  [23.1 18.6 14.4 ...  2.3  4.8 23.4]
#  [14.   9.1  5.  ...  1.3  2.1 23.8]
#  [ 5.4  6.   6.  ...  5.1  0.2 23.7]]

# %%
plt.imshow(imagen_mat_2)
plt.show()

# %%
plt.imshow(imagen_mat_2, cmap = 'gray')
plt.show()

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 25.5
# 255.0

# %%
print(np.min(imagen_mat_2))
print(np.min(imagen_mat))
# Out:
# 0.0
# 0.0
